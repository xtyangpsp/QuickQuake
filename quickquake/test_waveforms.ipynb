# %%
from obspy import read

# Ruta al archivo MSEED generado
path = "../data/20210919T150000/waveforms/2021-09-19T15-00-00.mseed"

# Leer trazas
st = read(path)

# Imprimir información básica
print(st)

# Visualizar
st.plot()
# Out:
# 33 Trace(s) in Stream:
#
# AV.DEER..BHE | 2021-09-19T15:00:00.000000Z - 2021-09-19T20:00:00.000000Z | 50.0 Hz, 900001 samples
# ...
# (31 other traces)
# ...
# AV.S12K..BHZ | 2021-09-19T15:00:00.000000Z - 2021-09-19T20:00:00.000000Z | 40.0 Hz, 720001 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
